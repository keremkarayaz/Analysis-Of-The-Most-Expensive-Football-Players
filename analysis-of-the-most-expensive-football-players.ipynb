# %% [markdown]
#    <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 style="text-align:center;">⚽️Welcome To My Most Expensive Players Analysis⚽️</h1>
#
#    </div>

# %% [markdown]
# <div id="animated-gif-container" >
#  <p style="text-align:center;"><img src="https://media.giphy.com/media/leGtI4JDAzrWo7jquD/giphy.gif" height="400" width="600" alt="Logo"></p>
# </div>

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 style="text-align:center;">What will we do in this analysis?</h1>
#
#    </div>

# %% [markdown]
# <h1 style="color:#FFFD6F ;"> 👉Introduction </h1>
#
# <p style="font-size:20px;font-family:Cursive">In this data analysis, the goals, assists, values, matches played, ages, countries of the players who played in 2021.
# So to put it briefly, the players have a lot of information.</p>

# %% [markdown]
# <h1 style="color:#E35535;"> 🎯 Objectives of Notbook </h1>
#
# <p style="font-size:20px;font-family:Cursive">-My Objectives is to filter among the players in the data set we use according to our wishes.</p>
# <p style="font-size:20px;font-family:Cursive">-Then I will try to get to know the data better by analyzing the average of the data, the correlation value, the total data.
#    </p>
# <p style="font-size:20px;font-family:Cursive">-I will add another data set to our data in addition to our set.
#     </p>
# <p style="font-size:20px;font-family:Cursive">-I will visualize the data by graphing it
#     </p>
# <p style="font-size:20px;font-family:Cursive">-I will calculate the precision of the data(there may be some problem here because the data is a bit big 🙄🙄)
#     </p>
#  <p style="font-size:20px;font-family:Cursive">-I'm going to make a decision tree of the data.
#     </p>
#  <p style="font-size:20px;font-family:Cursive">-Finally, I will do a regression analysis.
#     </p>

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="first" style="text-align:center;">Importing Libaries📚</h1>
#
#    </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns; sns.set()
from sklearn.datasets import make_blobs

# %%
df=pd.read_csv("/kaggle/input/most-expensive-footballers-2021/players.csv")

# %%
df.rename(columns={"Unnamed: 0":"Point","Markey Value In Millions(£)":"Market_Value"},inplace=True)

# %%
df.head()
# Out:
#    Point            Name        Position  Age  Market_Value  Country  \
# 0      0   Kylian Mbappé  Centre-Forward   22         144.0   France
# 1      1  Erling Haaland  Centre-Forward   21         135.0   Norway
# 2      2      Harry Kane  Centre-Forward   28         108.0  England
# 3      3   Jack Grealish     Left Winger   26          90.0  England
# 4      4   Mohamed Salah    Right Winger   29          90.0    Egypt
#
#                   Club  Matches  Goals  Own Goals  Assists  Yellow Cards  \
# 0  Paris Saint-Germain       16      7          0       11             3
# 1    Borussia Dortmund       10     13          0        4             1
# 2    Tottenham Hotspur       16      7          0        2             2
# 3      Manchester City       15      2          0        3             1
# 4         Liverpool FC       15     15          0        6             1
#
#    Second Yellow Cards  Red Cards  Number Of Substitute In  \
# ...

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="second" style="text-align:center;">Filtring🔍</h1>
#
#    </div>

# %%
teams=df.groupby(["Club","Name"])
teams.first()
# Out:
#                                              Point            Position  Age  \
# Club                    Name
# AC Milan                Alessio Romagnoli      439         Centre-Back   26
#                         Alexis Saelemaekers    476        Right Winger   22
#                         Ante Rebic             199         Left Winger   28
#                         Brahim Díaz            342  Attacking Midfield   22
#                         Davide Calabria        307          Right-Back   24
# ...                                            ...                 ...  ...
# Wolverhampton Wanderers Rúben Neves            117  Defensive Midfield   24
# Zenit St. Petersburg    Malcom                 362        Right Winger   24
#                         Sardar Azmoun          317      Centre-Forward   26
#                         Wendel                 468    Central Midfield   24
#                         Wilmar Barrios         491  Defensive Midfield   28
#
# ...

# %%
columns_show=["Matches","Goals","Assists"]
df.groupby(["Club"])[columns_show].agg([np.mean,np.std,np.min,np.max]).head(10)
# Out:
#                    Matches                         Goals                      \
#                       mean       std amin amax      mean       std amin amax
# Club
# AC Milan         13.153846  3.782551    6   20  1.461538  1.613246    0    5
# ACF Fiorentina   11.000000  2.828427    9   15  3.400000  4.979960    0   12
# AS Monaco        19.500000  2.777460   16   24  3.625000  2.973094    0    8
# AS Roma          13.555556  6.247222    0   18  2.666667  2.645751    0    8
# Ajax Amsterdam   15.833333  1.169045   14   17  4.333333  5.006662    0   14
# Al-Rayyan SC      3.000000       NaN    3    3  1.000000       NaN    1    1
# Arsenal FC        9.533333  2.614975    5   15  1.533333  2.199567    0    7
# Aston Villa       9.090909  2.071451    5   12  0.909091  1.044466    0    3
# Atalanta BC      12.500000  2.907670    8   16  1.666667  2.188122    0    8
# Athletic Bilbao   9.000000  4.082483    3   12  1.250000  1.500000    0    3
#
#                   Assists
# ...

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="third" style="text-align:center;">Add Column🖍</h1>
#
#    </div>

# %% [markdown]
#   <h1>Let's add a new column to the dataset</h1>

# %%
df["G\A"]=(
df["Goals"]
+df["Assists"])
def best_players(df):
    print(df[df["G\A"] > 16])
best_players(df)
# Out:
#      Point                Name            Position  Age  Market_Value  \
# 0        0       Kylian Mbappé      Centre-Forward   22         144.0
# 1        1      Erling Haaland      Centre-Forward   21         135.0
# 4        4       Mohamed Salah        Right Winger   29          90.0
# 58      58          Leroy Sané         Left Winger   25          54.0
# 63      63  Robert Lewandowski      Centre-Forward   33          54.0
# 96      96  Christopher Nkunku  Attacking Midfield   24          42.3
# 238    238       Thomas Müller      Second Striker   32          27.0
# 263    263    Sébastien Haller      Centre-Forward   27          24.3
# 333    333       Karim Benzema      Centre-Forward   33          22.5
# 387    387      Julián Álvarez      Centre-Forward   21          18.0
# 394    394       Karim Adeyemi      Centre-Forward   19          18.0
#
#            Country                       Club  Matches  Goals  Own Goals  \
# ...

# %%
df["Position"].value_counts()
# Out:
# Centre-Back           87
# Central Midfield      74
# Centre-Forward        70
# Right Winger          48
# Left Winger           46
# Attacking Midfield    41
# Defensive Midfield    41
# Right-Back            30
# Left-Back             23
# Goalkeeper            19
# Second Striker         8
# Left Midfield          8
# Right Midfield         5
# Name: Position, dtype: int64

# %% [markdown]
# <h1>In the data, there are football players who are mostly in the defender position.</h1>

# %%
df["Age"].unique()
# Out:
# array([22, 21, 28, 26, 29, 30, 24, 27, 18, 34, 23, 25, 20, 19, 33, 36, 31,
#        32, 17, 16])

# %%
def data_inv(df):
    print(df.describe())
    print("-"*70)
    print("Top 5 player",df["Name"][:5])
    print("-"*40)
    print("Means of goals:", df["Goals"].mean())
    print("Dataset variables:",df.shape[0])
    print("All assists:",df["Assists"].sum())
    print("-"*40)
    print(df.dtypes)
    print("-"*73)
    print("Correlation of data",df.corr())
    print("-"*81)
data_inv(df)
# Out:
#             Point         Age  Market_Value     Matches       Goals  \
# count  500.000000  500.000000    500.000000  500.000000  500.000000
# mean   249.500000   24.968000     31.537800   12.396000    2.160000
# std    144.481833    3.165916     17.577697    4.342453    2.880102
# min      0.000000   16.000000     16.200000    0.000000    0.000000
# 25%    124.750000   23.000000     19.800000   10.000000    0.000000
# 50%    249.500000   25.000000     25.200000   13.000000    1.000000
# 75%    374.250000   27.000000     36.000000   16.000000    3.000000
# max    499.000000   36.000000    144.000000   24.000000   23.000000
#
#         Own Goals    Assists  Yellow Cards  Second Yellow Cards   Red Cards  \
# count  500.000000  500.00000    500.000000           500.000000  500.000000
# mean     0.030000    1.51200      1.592000             0.036000    0.046000
# std      0.170758    1.85276      1.445585             0.186477    0.209695
# ...

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="four" style="text-align:center;">Missing Values🧹</h1>
#
#    </div>

# %%
df.isnull().sum()
# Out:
# Point                       0
# Name                        0
# Position                    0
# Age                         0
# Market_Value                0
# Country                     0
# Club                        0
# Matches                     0
# Goals                       0
# Own Goals                   0
# Assists                     0
# Yellow Cards                0
# Second Yellow Cards         0
# Red Cards                   0
# Number Of Substitute In     0
# Number Of Substitute Out    0
# G\A                         0
# dtype: int64

# %% [markdown]
# <h1>There is no empty data in the data</h1>

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="five" style="text-align:center;">Graphics📊</h1>
#
#    </div>

# %%
my_colors = ['g', 'b']*5 
my_colors = [(0.5,0.4,0.5), (0.75, 0.75, 0.25)]*5 


plt.figure(figsize=(12,8))
df["Country"].value_counts().plot(kind="bar",color=my_colors,edgecolor="red")
plt.grid()
plt.show()

# %%
explode=(0,0,0,0,0,0,0.7,0.5)
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
pie, ax = plt.subplots(figsize=[8,10])
labels = df["Yellow Cards"].value_counts().keys()
plt.pie(x=df["Yellow Cards"].value_counts(), autopct="%.1f%%", labels=labels, pctdistance=0.5,explode=explode,shadow=True,
       wedgeprops = wp)
plt.legend()
plt.title("Proportion of players by Yellow Cards", fontsize=14);

# %%
sns.set_style("white")
sns.set_style("ticks")
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="Age", color="lightblue", width=0.2);
plt.title("Boxplot of the age of players")
sns.despine(left=True);

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="five" style="text-align:center;">Benzema 🆚 Lewandowski</h1>
#
#    </div>

# %% [markdown]
# ![](https://e0.365dm.com/22/03/1600x900/skysports-robert-lewandowski_5699438.jpg?20220718160452)![](https://media.cnn.com/api/v1/images/stellar/prod/221017111358-01-karim-benzema.jpg?c=16x9&q=h_720,w_1280,c_fill)

# %%
df[df["Name"] == "Karim Benzema"],df[df["Name"] == "Robert Lewandowski"]
# Out:
# (     Point           Name        Position  Age  Market_Value Country  \
#  333    333  Karim Benzema  Centre-Forward   33          22.5  France
#
#              Club  Matches  Goals  Own Goals  Assists  Yellow Cards  \
#  333  Real Madrid       15     14          0        8             0
#
#       Second Yellow Cards  Red Cards  Number Of Substitute In  \
#  333                    0          0                        0
#
#       Number Of Substitute Out  G\A
#  333                         4   22  ,
#      Point                Name        Position  Age  Market_Value Country  \
#  63     63  Robert Lewandowski  Centre-Forward   33          54.0  Poland
#
#               Club  Matches  Goals  Own Goals  Assists  Yellow Cards  \
#  63  Bayern Munich       17     23          0        2             0
#
#      Second Yellow Cards  Red Cards  Number Of Substitute In  \
#  63                    0          0                        0
#
#      Number Of Substitute Out  G\A
# ...

# %%
import plotly.graph_objects as go
df_sorted = df.sort_values(by='G\A', ascending=False)
labels=np.array([
    "Goals",
    "Assists",
    "G\A",
    "Matches",
    "Market_Value"
])
stats=df_sorted.loc[63,labels].values
fig = go.Figure()
fig.add_trace(go.Scatterpolar(
      r=stats,
      theta=labels,
      fill='toself',
      name='R.Lewandowski'
))
stats=df_sorted.loc[333, labels].values
fig.add_trace(go.Scatterpolar(
      r=stats,
      theta=labels,
      fill='toself',
      name='K.Benzema'
))
fig.update_layout(
    autosize=False,
    width=500,
    height=500,)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="five" style="text-align:center;">Nkunku 🆚 Wirtz</h1>
#
#    </div>

# %% [markdown]
# ![](https://img.bundesliga.com/tachyon/sites/2/2021/04/nkunku-celebration-rbl-leipzig.jpg?crop=0px,0px,1920px,1080px)![](https://assets.goal.com/v3/assets/bltcc7a7ffd2fbf71f5/blt3fe203be71e93735/623b56a3660a2008c0d6516e/Florian_Wirtz_Bayer_Leverkusen_2021-22.jpg?auto=webp&format=jpg&quality=100)

# %%
df[df["Name"] == "Florian Wirtz"],df[df["Name"] == "Christopher Nkunku"]
# Out:
# (    Point           Name            Position  Age  Market_Value  Country  \
#  42     42  Florian Wirtz  Attacking Midfield   18          58.5  Germany
#
#                     Club  Matches  Goals  Own Goals  Assists  Yellow Cards  \
#  42  Bayer 04 Leverkusen       14      7          0        7             2
#
#      Second Yellow Cards  Red Cards  Number Of Substitute In  \
#  42                    0          0                        4
#
#      Number Of Substitute Out  G\A
#  42                         8   14  ,
#      Point                Name            Position  Age  Market_Value Country  \
#  96     96  Christopher Nkunku  Attacking Midfield   24          42.3  France
#
#            Club  Matches  Goals  Own Goals  Assists  Yellow Cards  \
#  96  RB Leipzig       17     11          0        7             0
#
#      Second Yellow Cards  Red Cards  Number Of Substitute In  \
#  96                    0          0                        1
#
#      Number Of Substitute Out  G\A
# ...

# %%
wirts_nkunku=df[df["Name"] == "Florian Wirtz"],df[df["Name"] == "Christopher Nkunku"]
df_sorted = df.sort_values(by='G\A', ascending=False)
labels=np.array([
    "Goals",
    "Assists",
    "G\A",
    "Matches",
    "Market_Value"
])
stats=df_sorted.loc[42,labels].values
fig = go.Figure()
fig.add_trace(go.Scatterpolar(
      r=stats,
      theta=labels,
      fill='toself',
      name='F.Wirtz'
))
stats=df_sorted.loc[96, labels].values
fig.add_trace(go.Scatterpolar(
      r=stats,
      theta=labels,
      fill='toself',
      name='C.Nkunku'
))

fig.update_layout(
    autosize=False,
    width=500,
    height=500,)
fig.show()
# Out:
# <div>                            <div id="51ec5aeb-65e5-4c9f-9376-70f0812fb08c" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51ec5aeb-65e5-4c9f-9376-70f0812fb08c")) {                    Plotly.newPlot(                        "51ec5aeb-65e5-4c9f-9376-70f0812fb08c",                        [{"fill":"toself","name":"F.Wirtz","r":[7,7,14,14,58.5],"theta":["Goals","Assists","G\\A","Matches","Market_Value"],"type":"scatterpolar"},{"fill":"toself","name":"C.Nkunku","r":[11,7,18,17,42.3],"theta":["Goals","Assists","G\\A","Matches","Market_Value"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,
# ...

# %%
plt.figure(figsize=(10,10))
heat_map = sns.heatmap(df.corr(), linewidth = 1 , annot = True)
plt.title( "Heat Map" )
plt.show()

# %%
df.drop(["Name","Position","Country","Club"],axis=1,inplace=False)

plt.figure(figsize=(30, 10))
sns.set_style("white")
plot = sns.boxplot(data=df, width=0.25)
plt.title("Box plot of players")
sns.despine()
plt.show()

# %%
def matches(df):
    y=df.loc[471,"Matches"]
    o=df.loc[113,"Matches"]
    r=df.loc[0,"Market_Value"]
    a=df.loc[63,"Goals"]
    d=df.loc[238,"Assists"]
    print("Youngest Player Matches:",y)
    print("Oldest Player Matches:",o) 
    print("Most Expensive Player:",r)
    print("Most Goals Scored:",a)
    print("Most Assisted:",d)
matches(df)
# Out:
# Youngest Player Matches: 11
# Oldest Player Matches: 14
# Most Expensive Player: 144.0
# Most Goals Scored: 23
# Most Assisted: 12

# %%
ages=[22,29,34,27,23,22,29,19,26,28,31,25,25,27,28,33]
g_and_a=[18,6,5,5,4,3,3,3,1,1,1,0,0,0,0,0]

plt.figure(figsize=(10,8))
plt.plot(g_and_a,ages,linewidth="2",label="G\A",marker="o",markersize=13,markerfacecolor="orange")
plt.grid(linestyle="--",linewidth=0.5)
plt.xlabel("Goal And Assists")
plt.ylabel("Ages")
plt.title("Paris Saint Germain Graph")
plt.legend()
plt.show()

# %%
df=df.drop(["Point","Number Of Substitute In","Number Of Substitute Out","Red Cards",
            "Yellow Cards","Second Yellow Cards"],axis=1,inplace=False)
plt.figure(figsize=(12,6))
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="seven" style="text-align:center;">Calculate Accuracy💾</h1>
#
#    </div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
df=df.drop(["Name","Position","Club"],axis=1,inplace=False)
X=df.drop(columns=["Country"])
Y=df["Country"]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

model=DecisionTreeClassifier()
model.fit(X_train,Y_train)
predictions=model.predict(X_test)

score=accuracy_score(Y_test,predictions)
score
# Out:
# 0.07

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="eight" style="text-align:center;">Decision Tree🌲</h1>
#
#    </div>

# %%
from sklearn import tree
X1=df.drop(columns=["Country"])
Y2=df["Country"]

model=DecisionTreeClassifier()
model.fit(X1,Y2)

tree.export_graphviz(model,out_file="Football.dot",feature_names=["Age","Market_Value","Matches","Goals","Own Goals","Assists","G\A"],class_names=sorted(Y2.unique()),
                    label="all",
                    rounded=True,
                    filled=True)

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="ten" style="text-align:center;">K-Means📈</h1>
#
#    </div>

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["Age"][:50] ,df["G\A"][:50])
plt.xlabel("Ages")
plt.ylabel("G\A")
plt.show()

# %%
from sklearn.cluster import KMeans
df=df.drop(["Country"],axis=1,inplace=False)
t=df.copy()
kmeans=KMeans(2)
kmeans.fit(t)
# Out:
# KMeans(n_clusters=2)

# %%
clusters=t.copy()
clusters["cluster_pred"]=kmeans.fit_predict(t)

# %%
plt.figure(figsize=(10,6))
plt.scatter(clusters["Age"],clusters["G\A"],c=clusters["cluster_pred"],cmap="rainbow")
plt.xlabel("Ages")
plt.ylabel("G\A")
plt.grid()
plt.show()

# %%
from sklearn import preprocessing
x_scaled=preprocessing.scale(t)
x_scaled
# Out:
# array([[-0.93842438,  6.4044131 ,  0.83077685, ..., -0.17586311,
#          5.126136  ,  3.50272665],
#        [-1.2546051 ,  5.89188785, -0.55231447, ..., -0.17586311,
#          1.34420598,  3.2582594 ],
#        [ 0.95865995,  4.35431208,  0.83077685, ..., -0.17586311,
#          0.26365455,  1.30252147],
#        ...,
#        [-0.30606294, -0.87344554, -1.70489057, ..., -0.17586311,
#         -0.81689688, -0.89768371],
#        [ 0.01011778, -0.87344554, -1.01334491, ..., -0.17586311,
#         -0.81689688, -0.89768371],
#        [ 0.64247923, -0.87344554,  0.60026163, ..., -0.17586311,
#         -0.27662117,  0.08018526]])

# %%
wcss=[]

for i in range(1,50):
    kmeans=KMeans(i)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)
wcss
# Out:
# [3500.0,
#  2561.6829256663887,
#  2065.228478091429,
#  1814.7952757087955,
#  1608.9915994157711,
#  1430.8580561450271,
#  1269.9928232550126,
#  1184.8984789719852,
#  1125.7136401433395,
#  1078.232800445492,
#  1014.8774342829994,
#  976.5320304622264,
#  935.6626013806863,
#  903.4583032735206,
#  854.5299528948445,
#  837.4106508944008,
#  810.8989131017797,
#  771.091262414141,
#  746.0136953764746,
#  722.0531312707352,
#  706.2246411441189,
#  688.73829030608,
#  675.3275592361041,
#  646.9134329604274,
#  642.5421293611321,
#  618.6688046135021,
#  612.3112477941867,
#  586.8510456476636,
#  587.6266013157317,
#  569.1290765259332,
#  551.679384072428,
#  549.7153124264962,
#  537.265456706918,
#  528.9831291697424,
#  516.5160601652275,
#  509.20921254890203,
#  498.96159933101205,
#  490.2301871061745,
#  481.8008168924535,
#  473.9355132781202,
#  468.0451132448108,
#  458.85007039402814,
#  451.07627352844855,
#  448.5278193522984,
#  443.47892100027263,
# ...

# %%
plt.plot(range(1,50),wcss)
plt.xlabel("K-Means")
plt.ylabel("WCSS")
plt.grid()
plt.show()

# %%
kmeans_new=KMeans(8)
kmeans.fit(x_scaled)
cluster_new=t.copy()
cluster_new["cluster_pred"]=kmeans_new.fit_predict(x_scaled)
cluster_new
# Out:
#      Age  Market_Value  Matches  Goals  Own Goals  Assists  G\A  cluster_pred
# 0     22         144.0       16      7          0       11   18             4
# 1     21         135.0       10     13          0        4   17             4
# 2     28         108.0       16      7          0        2    9             3
# 3     26          90.0       15      2          0        3    5             3
# 4     29          90.0       15     15          0        6   21             4
# ..   ...           ...      ...    ...        ...      ...  ...           ...
# 495   27          16.2        0      0          0        0    0             5
# 496   28          16.2        8      1          0        3    4             0
# 497   24          16.2        5      0          0        0    0             5
# 498   25          16.2        8      0          0        0    0             5
# 499   27          16.2       15      3          0        1    4             0
#
# [500 rows x 8 columns]

# %%
plt.figure(figsize=(10,6))
plt.scatter(cluster_new["Age"],cluster_new["G\A"],c=cluster_new["cluster_pred"],cmap="rainbow")
plt.xlabel("Ages")
plt.ylabel("G\A")
plt.grid()
plt.show()

# %%
df.describe()
# Out:
#               Age  Market_Value     Matches       Goals   Own Goals  \
# count  500.000000    500.000000  500.000000  500.000000  500.000000
# mean    24.968000     31.537800   12.396000    2.160000    0.030000
# std      3.165916     17.577697    4.342453    2.880102    0.170758
# min     16.000000     16.200000    0.000000    0.000000    0.000000
# 25%     23.000000     19.800000   10.000000    0.000000    0.000000
# 50%     25.000000     25.200000   13.000000    1.000000    0.000000
# 75%     27.000000     36.000000   16.000000    3.000000    0.000000
# max     36.000000    144.000000   24.000000   23.000000    1.000000
#
#          Assists         G\A
# count  500.00000  500.000000
# mean     1.51200    3.672000
# std      1.85276    4.094624
# min      0.00000    0.000000
# 25%      0.00000    1.000000
# 50%      1.00000    3.000000
# 75%      2.00000    5.000000
# max     12.00000   25.000000

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="eleven" style="text-align:center;">Linear Regression📉</h1>
#
#    </div>

# %%
r1=df["Matches"][:50]
r2=df["Goals"][:50]

# %%
plt.scatter(r1,r2)
plt.xlabel("Matches",fontsize=15)
plt.ylabel("Goals",fontsize=15)
plt.show()

# %%
import statsmodels.api as sm
R=sm.add_constant(r2)
results=sm.OLS(r1,R).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Matches   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     1.975
# Date:                Wed, 01 Mar 2023   Prob (F-statistic):              0.166
# Time:                        21:04:35   Log-Likelihood:                -126.26
# No. Observations:                  50   AIC:                             256.5
# Df Residuals:                      48   BIC:                             260.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.7918      0.605     21.158      0.000      11.576      14.007
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(r2,r1)
yhat= 0.1910*r2 + 12.7918
fig=plt.plot(r2,yhat,lw=4,c="orange",label="Regression Line")
plt.xlabel("Goals",fontsize=15)
plt.ylabel("Matches",fontsize=15)
plt.grid()
plt.show()

# %%
df.head()
# Out:
#    Age  Market_Value  Matches  Goals  Own Goals  Assists  G\A
# 0   22         144.0       16      7          0       11   18
# 1   21         135.0       10     13          0        4   17
# 2   28         108.0       16      7          0        2    9
# 3   26          90.0       15      2          0        3    5
# 4   29          90.0       15     15          0        6   21

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="last" style="text-align:center;">Results💎</h1>
#
#    </div>

# %% [markdown]
#  <p style="font-size:20px;font-family:Italic">🔴As a result, the player with the highest contribution to the goal in 2021 is Robert Lewandowski.
#     </p>

# %% [markdown]
#  <p style="font-size:20px;font-family:Italic">🟠The data includes the most defender players.

# %% [markdown]
#  <p style="font-size:20px;font-family:Italic">🟡The reason why I compared Benzema lewandowski and Nkunku Wirtz in our data is because they are the youngest top scorers and the oldest top scorers.

# %% [markdown]
#  <p style="font-size:20px;font-family:Italic">🟢The precision calculation process does not seem very suitable for this dataset. Therefore, the result of this procedure may be quite low.
#    I just wanted to show you how it's done

# %% [markdown]
#  <p style="font-size:20px;font-family:Italic">🔵In the decision tree process, since our data set is very large, the picture of the decision tree has become quite large. But I can still say that it works.

# %% [markdown]
#  <p style="font-size:20px;font-family:Italic">🟣We used a total of 8 different clusters to calculate the k value. Because the graph we made with the elbow trick method showed us to make a scatter graph with 8 clusters.

# %% [markdown]
# <div id="animated-gif-container" >
#  <p style="text-align:center;"><img src="https://media.giphy.com/media/JQ9FBlNO9gwGxUDwWj/giphy.gif" height="400" width="500" alt="Logo"></p>
# </div>

# %% [markdown]
# <div style="color:#FF5733;
#     background-color:#581845;
#     display:fill;
#     border-radius:5px;
#     font-size:130%;
#     height:45px;">
#   <h1 id="final" style="text-align:center;">👍🏽Thanks For Your Vote👍🏽</h1>
#
#    </div>
